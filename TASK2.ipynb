# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("Student_performance_data.csv")
data.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
data.tail()
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
#       Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 2387         2         0                4                1       0      0
# 2388         4         1                4                0       1      0
# 2389        20         0                2                0       0      0
# 2390        17         0                2                0       1      1
# 2391        13         0                2                0       0      0
#
#       Volunteering       GPA  GradeClass
# ...

# %%
data.shape
# Out:
# (2392, 15)

# %%
data.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
data.columns
# Out:
# Index(['StudentID', 'Age', 'Gender', 'Ethnicity', 'ParentalEducation',
#        'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport',
#        'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA',
#        'GradeClass'],
#       dtype='object')

# %%
data.nunique()
# Out:
# StudentID            2392
# Age                     4
# Gender                  2
# Ethnicity               4
# ParentalEducation       5
# StudyTimeWeekly      2392
# Absences               30
# Tutoring                2
# ParentalSupport         5
# Extracurricular         2
# Sports                  2
# Music                   2
# Volunteering            2
# GPA                  2371
# GradeClass              5
# dtype: int64

# %%
data['Gender'].unique()
# Out:
# array([1, 0])

# %%
student = data.drop(['Ethnicity', 'ParentalEducation', 'StudyTimeWeekly', 'ParentalSupport',
                    'Extracurricular', 'Tutoring', 'Music', 'Volunteering'], axis = 1)

# %%
student.head()
# Out:
#    StudentID  Age  Gender  Absences  Sports       GPA  GradeClass
# 0       1001   17       1         7       0  2.929196         2.0
# 1       1002   18       0         0       0  3.042915         1.0
# 2       1003   15       0        26       0  0.112602         4.0
# 3       1004   17       1        14       0  2.054218         3.0
# 4       1005   17       1        17       0  1.288061         4.0

# %%
#Relationship Analysis
correlation = student.corr()

# %%
correlation
# Out:
#             StudentID       Age    Gender  Absences    Sports       GPA  \
# StudentID    1.000000 -0.042255 -0.014625  0.014841 -0.020703 -0.002697
# Age         -0.042255  1.000000  0.044895 -0.011511 -0.046320  0.000275
# Gender      -0.014625  0.044895  1.000000  0.021479 -0.008897 -0.013360
# Absences     0.014841 -0.011511  0.021479  1.000000  0.041454 -0.919314
# Sports      -0.020703 -0.046320 -0.008897  0.041454  1.000000  0.057859
# GPA         -0.002697  0.000275 -0.013360 -0.919314  0.057859  1.000000
# GradeClass  -0.098500 -0.006250  0.022998  0.728633 -0.026654 -0.782835
#
#             GradeClass
# StudentID    -0.098500
# Age          -0.006250
# Gender        0.022998
# Absences      0.728633
# Sports       -0.026654
# GPA          -0.782835
# GradeClass    1.000000

# %%
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, cmap='Pastel1', annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(student)

# %%
sns.relplot(x = 'StudentID', y = 'GPA', hue = 'Gender', palette = "twilight", data = student)

# %%
sns.displot(student['Absences'])

# %%
sns.catplot(x='Absences', kind='box', data=student)

# %%
sns.catplot(x='Absences', kind='count', data=student)

# %%
sns.catplot(x='Absences', kind='swarm', data=student)
# Out:
# C:\Users\waghs.DESKTOP-OFO3QK6\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 41.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='Absences', kind='point', data=student)

# %%
sns.catplot(x='Absences', kind='bar', data=student)

# %%
sns.catplot(x='Absences', kind='violin',data=student)

# %%
sns.catplot(x='Absences', kind='strip', data=student)
